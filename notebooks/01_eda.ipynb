# %%
import pandas as pd

# %%
df = pd.read_csv("../datos/datos_crudos/datos_moodle.csv")

# %%
df.head()
# Out:
#    codigo_estudiante  edad sexo periodo_academico  nota_primer_parcial  \
# 0           20248998    21    M           2025-II                    7
# 1           20248134    19    M           2025-II                    5
# 2           20254712    20    F           2025-II                   12
# 3           20257253    17    M           2025-II                   14
# 4           20256938    20    M           2025-II                   19
#
#    nota_segundo_parcial  nota_tercer_parcial  promedio_previo  \
# 0                    17                   20              7.5
# 1                    18                   15             10.9
# 2                    13                   16              7.7
# 3                    11                   15             14.2
# 4                    19                   16             15.2
#
#    total_accesos_lms  tiempo_total_conexion_min  tareas_entregadas  \
# 0                 81                        623                  7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471 entries, 0 to 470
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   codigo_estudiante            471 non-null    int64
#  1   edad                         471 non-null    int64
#  2   sexo                         471 non-null    object
#  3   periodo_academico            471 non-null    object
#  4   nota_primer_parcial          471 non-null    int64
#  5   nota_segundo_parcial         471 non-null    int64
#  6   nota_tercer_parcial          471 non-null    int64
#  7   promedio_previo              471 non-null    float64
#  8   total_accesos_lms            471 non-null    int64
#  9   tiempo_total_conexion_min    471 non-null    int64
#  10  tareas_entregadas            471 non-null    int64
#  11  tareas_totales               471 non-null    int64
#  12  participaciones_foro         471 non-null    int64
# ...

# %%
df.describe()
# Out:
#        codigo_estudiante        edad  nota_primer_parcial  \
# count       4.710000e+02  471.000000           471.000000
# mean        2.025096e+07   19.048832            12.405520
# std         5.687779e+03    1.412616             4.641979
# min         2.024111e+07   17.000000             5.000000
# 25%         2.024610e+07   18.000000             8.000000
# 50%         2.025155e+07   19.000000            12.000000
# 75%         2.025635e+07   20.000000            16.000000
# max         2.025999e+07   21.000000            20.000000
#
#        nota_segundo_parcial  nota_tercer_parcial  promedio_previo  \
# count            471.000000           471.000000       471.000000
# mean              12.360934            16.008493        12.867728
# std                4.793755             2.618253         4.611962
# min                5.000000            12.000000         5.000000
# 25%                8.000000            14.000000         8.850000
# ...
